# %%
import pandas as pd

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')
    
def print_nulls(df):
    out = pd.Series({'Column': 'Percentage of nulls', '-----' : '-----'}
                   ).append(df.isnull().sum()*100/df.isnull().isnull().count())
   
    return print_full(out)

# %% [markdown]
# ### About the Data
#
# These are fuel estimates for vehicles done by the epa. I accessed the [data here](https://www.fueleconomy.gov/feg/download.shtml). The dictionary is available [here](https://www.fueleconomy.gov/feg/ws/index.shtml#vehicle).

# %%
df = pd.read_csv('vehicles.csv')
# Out:
# /home/owen/.conda/envs/MLOPS/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43156 entries, 0 to 43155
# Data columns (total 83 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   barrels08        43156 non-null  float64
#  1   barrelsA08       43156 non-null  float64
#  2   charge120        43156 non-null  float64
#  3   charge240        43156 non-null  float64
#  4   city08           43156 non-null  int64
#  5   city08U          43156 non-null  float64
#  6   cityA08          43156 non-null  int64
#  7   cityA08U         43156 non-null  float64
#  8   cityCD           43156 non-null  float64
#  9   cityE            43156 non-null  float64
#  10  cityUF           43156 non-null  float64
#  11  co2              43156 non-null  int64
#  12  co2A             43156 non-null  int64
#  13  co2TailpipeAGpm  43156 non-null  float64
#  14  co2TailpipeGpm   43156 non-null  float64
#  15  comb08           43156 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
# ...

# %%
print_nulls(df)
# Out:
# Column             Percentage of nulls
# -----                            -----
# barrels08                            0
# barrelsA08                           0
# charge120                            0
# charge240                            0
# city08                               0
# city08U                              0
# cityA08                              0
# cityA08U                             0
# cityCD                               0
# cityE                                0
# cityUF                               0
# co2                                  0
# co2A                                 0
# co2TailpipeAGpm                      0
# co2TailpipeGpm                       0
# comb08                               0
# comb08U                              0
# combA08                              0
# combA08U                             0
# combE                                0
# combinedCD                           0
# combinedUF                           0
# ...

# %%
df[['city08'
    , 'city08U'
    , 'cityA08'
    , 'cityA08U'
    , 'cityCD'
    , 'cityE'
    , 'cityUF']].describe()
# Out:
#              city08       city08U       cityA08      cityA08U        cityCD  \
# count  43156.000000  43156.000000  43156.000000  43156.000000  43156.000000
# mean      18.596510      6.786865      0.755306      0.617080      0.000500
# std        8.531435     12.438950      5.869488      5.753763      0.038345
# min        6.000000      0.000000      0.000000      0.000000      0.000000
# 25%       15.000000      0.000000      0.000000      0.000000      0.000000
# 50%       17.000000      0.000000      0.000000      0.000000      0.000000
# 75%       21.000000     15.717025      0.000000      0.000000      0.000000
# max      150.000000    150.000000    145.000000    145.083500      5.350000
#
#               cityE        cityUF
# count  43156.000000  43156.000000
# mean       0.438133      0.002354
# std        4.501560      0.035651
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# ...

# %%
df[['UCity'
    , 'UCityA'
    , 'UHighway'
    , 'UHighwayA' ]].describe()
# Out:
#               UCity        UCityA      UHighway     UHighwayA
# count  43156.000000  43156.000000  43156.000000  43156.000000
# mean      23.528372      0.991406     34.687040      1.268237
# std       12.112496      8.267662     11.819721      8.603163
# min        0.000000      0.000000      0.000000      0.000000
# 25%       18.400000      0.000000     28.000000      0.000000
# 50%       21.600000      0.000000     33.333300      0.000000
# 75%       26.000000      0.000000     39.283200      0.000000
# max      224.800000    207.262200    187.100000    173.143600

# %%
# Columns that I want

df[['make', 'model', 'year', 'engId', 'city08', '']]
# Out:
#              make                model  year  engId  city08
# 0      Alfa Romeo   Spider Veloce 2000  1985   9011      19
# 1         Ferrari           Testarossa  1985  22020       9
# 2           Dodge              Charger  1985   2100      23
# 3           Dodge  B150/B250 Wagon 2WD  1985   2850      10
# 4          Subaru     Legacy AWD Turbo  1993  66031      17
# ...           ...                  ...   ...    ...     ...
# 43151      Subaru               Legacy  1993  66030      19
# 43152      Subaru               Legacy  1993  66030      20
# 43153      Subaru           Legacy AWD  1993  66030      18
# 43154      Subaru           Legacy AWD  1993  66030      18
# 43155      Subaru     Legacy AWD Turbo  1993  66031      16
#
# [43156 rows x 5 columns]

# %%
df.year.describe()
# Out:
# count    43156.000000
# mean      2002.422606
# std         11.594615
# min       1984.000000
# 25%       1992.000000
# 50%       2003.000000
# 75%       2013.000000
# max       2021.000000
# Name: year, dtype: float64

# %%
df[df['charge240'] > 0].describe()
# Out:
#         barrels08  barrelsA08  charge120   charge240      city08     city08U  \
# count  440.000000  440.000000      440.0  440.000000  440.000000  440.000000
# mean     3.070591    1.708235        0.0    5.986068   71.336364   70.375143
# std      3.631715    2.603178        0.0    3.756052   42.398646   42.978911
# min      0.144000    0.000000        0.0    0.670000   16.000000    0.000000
# 25%      0.192000    0.000000        0.0    3.000000   28.000000   27.332300
# 50%      0.276000    0.000000        0.0    4.000000   76.000000   73.150000
# 75%      5.995175    3.683142        0.0   10.000000  114.250000  114.555000
# max     14.386492   18.311667        0.0   15.300000  150.000000  150.000000
#
#           cityA08    cityA08U      cityCD       cityE  ...       UCity  \
# count  440.000000  440.000000  440.000000  440.000000  ...  440.000000
# mean    34.929545   34.877669    0.049060   39.793350  ...   99.087325
# ...

# %%
df[df['cityE'] > 0].describe()
# Out:
#         barrels08  barrelsA08  charge120   charge240     city08     city08U  \
# count  463.000000  463.000000      463.0  463.000000  463.00000  463.000000
# mean     2.937223    1.623377        0.0    5.688704   70.87689   66.879186
# std      3.588125    2.564611        0.0    3.885982   41.61746   44.604261
# min      0.144000    0.000000        0.0    0.000000   16.00000    0.000000
# 25%      0.192000    0.000000        0.0    3.000000   28.00000   25.500000
# 50%      0.282000    0.000000        0.0    4.000000   73.00000   55.220600
# 75%      5.728244    3.469579        0.0    9.500000  112.00000  112.000000
# max     14.386492   18.311667        0.0   15.300000  150.00000  150.000000
#
#           cityA08    cityA08U      cityCD       cityE  ...       UCity  \
# count  463.000000  463.000000  463.000000  463.000000  ...  463.000000
# mean    33.194384   33.145085    0.046623   40.838172  ...   98.540042
# ...

# %%
df['fuelType1'].unique()
# Out:
# array(['Regular Gasoline', 'Premium Gasoline', 'Diesel', 'Natural Gas',
#        'Electricity', 'Midgrade Gasoline'], dtype=object)

# %%
df['fuelType2'].unique()
# Out:
# array([nan, 'Natural Gas', 'E85', 'Propane', 'Electricity'], dtype=object)

# %%
df[df['fuelType1'] == 'Electricity'].describe()
# Out:
#         barrels08  barrelsA08  charge120   charge240      city08     city08U  \
# count  257.000000       257.0      257.0  257.000000  257.000000  257.000000
# mean     0.218335         0.0        0.0    7.812840  103.891051   96.835161
# std      0.074746         0.0        0.0    3.981239   24.221548   38.499826
# min      0.144000         0.0        0.0    0.000000   28.000000    0.000000
# 25%      0.180000         0.0        0.0    4.000000   88.000000   86.098200
# 50%      0.198000         0.0        0.0    8.000000  105.000000  104.231400
# 75%      0.228000         0.0        0.0   12.000000  124.000000  124.000000
# max      0.726000         0.0        0.0   15.300000  150.000000  150.000000
#
#        cityA08  cityA08U  cityCD       cityE  ...       UCity  UCityA  \
# count    257.0     257.0   257.0  257.000000  ...  257.000000   257.0
# mean       0.0       0.0     0.0   35.009237  ...  145.438144     0.0
# ...

# %%
df[df['fuelType2'] == 'Electricity'].describe()
# Out:
#         barrels08  barrelsA08  charge120   charge240      city08     city08U  \
# count  206.000000  206.000000      206.0  206.000000  206.000000  206.000000
# mean     6.329233    3.648658        0.0    3.038689   29.689320   29.506926
# std      2.859847    2.719785        0.0    1.235068    9.981475   10.211434
# min      1.049516    0.174000        0.0    0.670000   16.000000    0.000000
# 25%      3.795078    0.426000        0.0    2.300000   21.250000   21.235600
# 50%      6.422289    3.745568        0.0    3.000000   27.000000   26.709250
# 75%      8.252344    5.274757        0.0    3.000000   37.000000   37.292000
# max     14.386492   18.311667        0.0    9.000000   55.000000   55.220600
#
#           cityA08    cityA08U      cityCD       cityE  ...       UCity  \
# count  206.000000  206.000000  206.000000  206.000000  ...  206.000000
# mean    74.606796   74.495991    0.104788   48.110194  ...   40.031245
# ...

# %%
df['evMotor'].value_counts().sum()
# Out:
# 1158
